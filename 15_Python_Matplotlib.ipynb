# %% [markdown]
# To start, click File --> Save as Copy in Drive (collab notebook) or Make a Copy (Jupyter Notebook)
#
# Then you can have your own copy you can modify.

# %% [markdown]
# Reference:
#
# Part IV: "Visualization with Matplotlib", VanderPlas, Jake. *Python Data Science Handbook*, 2nd Edition, O'Reilly, 2022
#
# You can find the book and code from the book here: https://github.com/jakevdp/PythonDataScienceHandbook

# %% [markdown]
# Here is the documentation for [matplotlib](https://matplotlib.org/3.5.0/index.html).

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt # You'll mostly use this
import numpy as np    # We need this
import pandas as pd   # Just in case we need this

# %%
# Make some data
t = np.arange(0.0, 2.0, 0.01)
s = np.sin(2*np.pi*t)

# start the figure
fig = plt.figure()
plt.plot(t, s) # line plot
fig.savefig('test.png')  # Save figure. Put the image extention you want.

# %%
fig.canvas.get_supported_filetypes()  # Find the supported extentions.
# Out:
# {'eps': 'Encapsulated Postscript',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format',
#  'webp': 'WebP Image Format'}

# %% [markdown]
# # Line Plots

# %%
fig = plt.figure()  # Create a figure; container for objects
ax = plt.axes()     # Create an axes; contain the plot elements

# some data
t = np.arange(0.0, 2.0, 0.01)
s = np.sin(2*np.pi*t)

ax.plot(t, s); # the semicolon suppresses a message.

# %%
plt.plot(t, s);  # this does the same thing.

# %%
fig = plt.figure()  # Create a figure; container for objects
ax = plt.axes()     # Create an axes; contain the plot elements
t = np.arange(0.0, 2.0, 0.01)
s = np.sin(2*np.pi*t)
c = np.cos(2*np.pi*t)
plt.plot(t, s);
# Add another line
plt.plot(t, c);

# %%
fig = plt.figure()  # Create a figure; container for objects
ax = plt.axes()     # Create an axes; contain the plot elements
t = np.arange(0.0, 2.0, 0.01)
s = np.sin(2*np.pi*t)
c = np.cos(2*np.pi*t)
plt.plot(t, s,color= '0');  # 0 is code for black
plt.plot(t, c, color='red'); # you can just type the name of certain colors.

# %% [markdown]
# There are different ways to get a color:
#
# * You can specify by color name. You can find them here: https://matplotlib.org/stable/gallery/color/named_colors.html
# * You can use the short color code (r-red, g- green, b- blue, c- cyan, m- magenta, y- yellow, k- black)
# * Grayscale of values between 0 (black) to 1(white).
# * Hex code or RRGGBB and 00 to FF.
# * RGB tuple, values 0 to 1.  Example (1.0,0.5,0.3)

# %%
fig = plt.figure()  # Create a figure; container for objects
ax = plt.axes()     # Create an axes; contain the plot elements
t = np.arange(0.0, 2.0, 0.01)
s = np.sin(2*np.pi*t)
c = np.cos(2*np.pi*t)
plt.plot(t, s,color= '0',linestyle = 'dashed');
plt.plot(t, c, color='red',linestyle = '-.');


# There are different linestyles
# You can type the words: solid, dashed, dashdot, dotted
# You can use these codes: - , -- , -. , or :

# %%
fig = plt.figure()  # Create a figure; container for objects
ax = plt.axes()     # Create an axes; contain the plot elements
t = np.arange(0.0, 2.0, 0.01)
s = np.sin(2*np.pi*t)
c = np.cos(2*np.pi*t)
plt.plot(t, s,'-g');
plt.plot(t, c, '--c');

# Short hand color and linestyle

# %%
fig = plt.figure()  # Create a figure; container for objects
ax = plt.axes()     # Create an axes; contain the plot elements
t = np.arange(0.0, 2.0, 0.01)
s = np.sin(2*np.pi*t)
c = np.cos(2*np.pi*t)
plt.plot(t, s);
plt.plot(t, c);

# you can change the axis limits
plt.xlim(0.5, 1.75);
plt.ylim(-1.5, 1.5);
plt.grid()  # this can add a grid

# plt.axis('tight');
# plt.axis('equal'); # other options are on, off, square, image

# %%
fig = plt.figure()  # Create a figure; container for objects
ax = plt.axes()     # Create an axes; contain the plot elements
t = np.arange(0.0, 2.0, 0.01)
s = np.sin(2*np.pi*t)
c = np.cos(2*np.pi*t)
plt.plot(t, s);
plt.plot(t, c);

# Addlabels to the graph
plt.title('Time Series')
plt.xlabel('Time')
plt.ylabel('Amplitude');

# %%
fig = plt.figure()  # Create a figure; container for objects
ax = plt.axes()     # Create an axes; contain the plot elements
t = np.arange(0.0, 2.0, 0.01)
s = np.sin(2*np.pi*t)
c = np.cos(2*np.pi*t)
plt.plot(t, s, label = 'sin(t)'); # You have to add a label here
plt.plot(t, c, label = 'cos(t)'); # Add the other label

plt.legend(); # display the legend

# %% [markdown]
# Since Matplotlib was based on MatLab type plotting it has both MatLab style
# functions and object oriented ones.  MatLab tends to add upon plots while
# object oriented sets everything at once.  But there are a few differences
# with the functions.
#
#
# | Matlab Style | Object Oriented    |
# |--------------|--------------------|
# | plt.xlabel   | ax.set_xlabel      |
# | plt.ylabel   | ax.set_ylabel      |
# | plt.xlim     | ax.set_xlim        |
# | plt.ylim     | ax.set_ylim        |
# | plt.title    | ax.set_title       |

# %%
# Here you can set everything at once
fig = plt.figure()  # Create a figure; container for objects
ax = plt.axes()     # Create an axes; contain the plot elements
t = np.arange(0.0, 2.0, 0.01)
s = np.sin(2*np.pi*t)
ax.set(xlabel='time (s)', ylabel='Amplitude', title='Time Series')  # everything set in one line
ax.plot(t, s);
ax.grid()

# %% [markdown]
# # Scatter Plots

# %% [markdown]
# ## Using plt.plot()

# %%
t = np.arange(0.0, 2.0, 0.05)  # I changed this a little so that the dots are spread out a bit. (0.01 --> 0.05)
s = np.sin(2*np.pi*t)
plt.plot(t, s, 'o');  # you can just put 'o'.

# %% [markdown]
# There are other markers you can use:
#
# o - big dot
#
# . - little dot
#
# , - very little dot
#
# x - an x shape
#
# \+ - a plus shape
#
# v - downward triangle
#
# ^ - upward triangle
#
# \> - right pointing triangle
#
# < - left pointing triangle
#
# s - square
#
# d - diamond
#
# And more can be found [here](https://matplotlib.org/stable/gallery/lines_bars_and_markers/marker_reference.html#sphx-glr-gallery-lines-bars-and-markers-marker-reference-py).

# %%
plt.plot(t, s, '-ok');
# This code means -  put the line, o put the scatter points, and k make it black.

# %%
# you can put all the parameters in the plot function for the marker style

plt.plot(t, s, '-p', color='green',  # the -p means line with pentagon markers
         markersize = 12,            # you can increase the size of the marker
         markerfacecolor = 'pink',   # this is the face color of the marker
         markeredgecolor = 'black',  # this is the edge color
         markeredgewidth = 2);       # this is the thickness of the edge color

# %% [markdown]
# ## Using plt.scatter()

# %%
plt.scatter(t, s);  # you can use the function scatter

# %%
plt.scatter(t, s, marker = 'v', color = 'r');  # marker allows the different shape and color here changes the marker color not the line color.

# %%
# you can also change the size of the scatter points
x = np.random.randint(1, 11, 10)
y = np.random.randint(1, 11, 10)
sizes = np.random.randint(10, 1000, 10)
plt.scatter(x, y, s = sizes);

# %%
from sklearn.datasets import load_iris  # Let's load the iris dataset we worked on in the pandas lesson
iris = load_iris()
attributes = iris.data.T

# Plot
fig = plt.figure()  # Create a figure; container for objects
ax = plt.axes()     # Create an axes; contain the plot elements
ax.scatter(attributes[1], attributes[2], c = iris.target, cmap = 'cool', # the data for two of the columns, c is the different color points  based on iris.target or the species of iris, cmap is the name for the color map see note below
            alpha= 0.3, # alpha makes the markers transparent; 0-completely transparent to 1 not transparent at all
            s = 100*attributes[3]); # This changes size depending on
ax.set_xlabel(iris.feature_names[1]);
ax.set_ylabel(iris.feature_names[2]);

# %% [markdown]
# cmap is the the color map you can use to create your figures.  There are many to choose from you can find more [here](https://matplotlib.org/stable/users/explain/colors/colormaps.html).

# %% [markdown]
# It is better to use plt.plot over plt.scatter for large datasets since all the data points are the same size for plt.plot, which leads to faster rendering.

# %% [markdown]
# ## plt.errorbar()

# %%
t = np.arange(0.0, 2.0, 0.05)  # I changed this a little so that the dots are spread out a bit. (0.01 --> 0.05)
s = np.sin(2*np.pi*t)
plt.errorbar(t, s, yerr = 0.2, fmt = 'ok'); # The error is set ot 0.2

# %%
plt.errorbar(t, s, yerr = 0.2, fmt = 'o',
             color = 'red', # change the dot color
             ecolor='blue', # change the errorbar color
             elinewidth=3,  # change the line width
             capsize = 3);  # change the size of the caps on the errorbars.

# %%
t = np.arange(0.0, 2.0, 0.05)  # I changed this a little so that the dots are spread out a bit. (0.01 --> 0.05)
s = np.sin(2*np.pi*t)
plt.plot(t,s,'-or')
plt.fill_between(t,s-0.2,s+0.2,  # x-axis variable, y error below, y error above.  This does not need to be static.  Functions can be place in here.
                 color = 'gray', # color
                 alpha = 0.3);  # how transparent

# %%
t = np.arange(0.0, 2.0, 0.05)  # I changed this a little so that the dots are spread out a bit. (0.01 --> 0.05)
s = np.sin(2*np.pi*t)
tfit = np.arange(0.0, 2.0, 0.05)
sfit = 0.2*np.sin(2*np.pi*tfit)
plt.plot(t,s,'-or')
plt.fill_between(tfit,s-sfit,s+sfit,  # x-axis variable, y error below, y error above.  This does not need to be static.  Functions can be place in here.
                 color = 'gray', # color
                 alpha = 0.3);  # how transparent

# %% [markdown]
# # Density and Contour Plots

# %% [markdown]
# ## Contours

# %%
# Lets make a 2D function so that we can plot it in a contour plot

def weird_guassian(x,y):
  x_guass1 = np.exp(-(x+1.5)**2)
  y_guass1 = np.exp(-(y-1.5)**2)
  x_guass2 = np.exp(-(x-1.5)**2)
  y_guass2 = np.exp(-(y+1.5)**2)
  x_guass3 = np.exp(-(x)**2)
  y_guass3 = np.exp(-y**2)
  z = x_guass1 * y_guass1 + x_guass2 * y_guass2 +x_guass3 * y_guass3

  return z

# %%
# Let's create the data

x = np.linspace(-2, 2, 100)
y = np.linspace(-2, 2, 100)
X,Y = np.meshgrid(x,y)
Z = weird_guassian(X,Y)

# %%
# Now plot!
plt.contour(X,Y,Z);

# %%
# We can add more line divisions by putting a number in the forth entry.  cmap gives us different color maps.
plt.contour(X,Y,Z, 25, cmap = 'cool');

# %%
plt.contourf(X,Y,Z, 25, cmap = 'RdGy');
plt.colorbar();  # We can add a color bar

# %%
# Let's make a smooth map, but this involves some interpolation.
plt.imshow(Z, extent = [-2,2,-2,2],  # The extremes of the data in x and y
           origin = 'lower', # Sometimes the graph gets flipped so we want to make sure the origin of the graph is near the bottom.
           cmap = 'RdGy',
           interpolation= 'gaussian',  # guassian smoothing
           aspect='equal');  #an x unit is the same as the y unit in length; here it should be a perfect square plot.
plt.colorbar();

# %%
ct = plt.contour(X,Y,Z,5, colors = 'black');
plt.clabel(ct);

plt.imshow(Z, extent = [-2,2,-2,2],  # The extremes of the data in x and y
           origin = 'lower', # Sometimes the graph gets flipped so we want to make sure the origin of the graph is near the bottom.
           cmap = 'RdGy',
           interpolation= 'gaussian',  # guassian smooting
           aspect='equal',
           alpha = 0.75);  # Transparency
plt.colorbar();

# %% [markdown]
# ## Histograms

# %%
hist_data = np.random.randn(1000)  # random numbers from a normal distribution.
plt.hist(hist_data);

# %%
hist_data = np.random.randn(1000)  # random numbers from a normal distribution.
plt.hist(hist_data,
         bins = 25,   # you can control the number o bins
         density= True,
         alpha = 0.75, # transparency
         histtype= 'bar', #stepfilled;  There are different types of styles.
         color = 'orchid', # color
         edgecolor = 'black'); # edge color

# %%
rng = np.random.default_rng(seed=12345)
dist1 = rng.normal(0,0.5,1000)  # another way to get normally distributed numbers
dist2 = rng.normal(-2,2,1000)
dist3 = rng.normal(1,1,1000)

att = dict(histtype='stepfilled', alpha=0.3, density=True, bins=40)  # put all the plot attributes into one place
plt.hist(dist1, **att);  # Use the attributes here.  ** unpacks dictinary
plt.hist(dist2, **att);
plt.hist(dist3, **att);

# %%
# create 2d historgram data
mean = [0,0]
covar = [[2,1],[1,1]]
x1, x2 = rng.multivariate_normal(mean,covar,10000).T  # .T transposes the matrix

# %%
plt.hist2d(x1,x2, bins = 30, cmap = 'Blues');
plt.colorbar();

# %%
plt.hexbin(x1,x2, gridsize = 30, cmap = 'Blues');
plt.colorbar(label = 'Counts');

# %% [markdown]
# # Customizing Plot Legends

# %%
# create data
t = np.arange(0.0, 2.0, 0.01)
s = np.sin(2*np.pi*t)
c = np.cos(2*np.pi*t)

# initialize figure
fig, ax = plt.subplots()

# plot figure
ax.plot(t, s,'-r', label = 'sin(t)'); # You have to add a label here
ax.plot(t, c,'--k', label = 'cos(t)'); # Add the other label

leg = ax.legend(); # display the legend

# %%
ax.legend(loc = 'upper left', frameon = True);  # change legend location; frameon will put a frame around the legend
fig

# %%
ax.legend(loc = 'lower center',
          frameon = True,
          ncol = 2);  # number of columns in the legend
fig

# %%
ax.legend(loc = 'lower center',
          frameon = True,
          fancybox = True,  # a rounded box
          shadow = True,   # add a shadow
          framealpha = 1,  # transparent (1 is not transparent at all)
          ncol = 2);  # number of columns in the legend
fig

# %%
# ignore some entries

# make more data
t = np.arange(0.0, 2.0, 0.01)
s = np.sin(2*np.pi*t)
c = np.cos(2*np.pi*t)
s2 = np.sin(2*np.pi*t)*np.exp(-t)
c2 = np.cos(2*np.pi*t)*np.exp(-t)

# initialize figure
fig, ax = plt.subplots()

# plot figure
ax.plot(t, s,'-r', label = 'sin(t)'); # You have to add a label here
ax.plot(t, c,'--k', label = 'cos(t)'); # Add the other label
ax.plot(t,s2,'-b');
ax.plot(t,c2,'-.g');


leg = ax.legend(); # display the legend and ignores those not labelled

# %%
# ignore some entries

# make more data
t = np.arange(0.0, 2.0, 0.01)
s = np.sin(2*np.pi*t)
c = np.cos(2*np.pi*t)
s2 = np.sin(2*np.pi*t)*np.exp(-t)
c2 = np.cos(2*np.pi*t)*np.exp(-t)

# initialize figure
fig, ax = plt.subplots()

# plot figure
ax.plot(t, s,'-r'); # You have to add a label here
ax.plot(t, c,'--k'); # Add the other label
ax.plot(t,s2,'-b');
ax.plot(t,c2,'-.g');

leg = ax.legend(['sine','cosine']); # display the legend and ignores those not labelled

# %%
# Create sample dataset
data = pd.DataFrame({
    'x': np.random.rand(10) * 100,        # x-coordinates between 0 and 100
    'y': np.random.rand(10) * 100,        # y-coordinates between 0 and 100
    'size': np.random.rand(10) * 1000,    # bubble size between 0 and 1000
    'color': np.random.rand(10) * 100     # bubble color scale between 0 and 100
})

# Create bubble plot
plt.figure(figsize=(8, 6))
scatter = plt.scatter(
    data['x'],
    data['y'],
    s=data['size'],        # Bubble size
    c=data['color'],       # Bubble color
    cmap='viridis',        # Color map
    alpha=0.6,              # Transparency
    edgecolors='w'          # White edge color
)

plt.colorbar(scatter, label='Color scale')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title('Bubble Plot Example')
plt.grid(True)


sizes_legend = [100, 300, 700]   # sizes of bubbles to put in legend.
for sz in sizes_legend:
  plt.scatter([],[],c = 'k', alpha =0.3, s = sz,
              label = str(sz));

plt.legend(scatterpoints=1, frameon=False, labelspacing=1,
          title='Size')


# If you run this multple times you may notice the legend jumping around, but its finding the optimum place based on where the data is.

# %% [markdown]
# # Colorbars

# %%
# Let's make a smooth map, but this involves some interpolation.
x = np.linspace(-10, 10, 100)
y = np.linspace(-10, 10, 100)

Z = np.sin(x)*np.cos(y[:,np.newaxis])

plt.imshow(Z)  # Notice how the x and y axis are not labelled properly and the y axis is flipped.
plt.colorbar();

# %%
plt.imshow(Z, cmap ='RdGy');
plt.colorbar();

# %%
# find more colormaps
# Press tab after the plt.cm.<TAB>
# plt.cm.

# %% [markdown]
# You can find more colormaps here:
#
# https://matplotlib.org/stable/users/explain/colors/colormaps.html

# %%
# What if there is noise
x = np.linspace(-10, 10, 100)
y = np.linspace(-10, 10, 100)
Z = np.sin(x)*np.cos(y[:,np.newaxis])

Z_speckle = Z.copy()

Z_speckle[25,25]= -3
Z_speckle[75,75]= 3

plt.subplot(1,2,1)
plt.imshow(Z_speckle, cmap ='RdGy');
plt.colorbar();

# You can designate the limits of the colorbar.
plt.subplot(1,2,2)
plt.imshow(Z_speckle, cmap ='RdGy');
plt.colorbar(extend = 'both'); # puts arrows to show there are larger and smaller values than displayed.
plt.clim(-1,1) # Limit the colorbar.

# %%
plt.imshow(Z_speckle, cmap ='RdGy');
plt.colorbar();

# %%
# You can designate the limits of the colorbar.
plt.imshow(Z_speckle, cmap =plt.get_cmap('Reds',6));
plt.colorbar(extend = 'both'); # puts arrows to show there are larger and smaller values than displayed.
plt.clim(-1,1); # Limit the colorbar.

# %% [markdown]
# # Subplots

# %%
ax1 = plt.axes()
ax2 = plt.axes([0.25, 0.55, 0.2, 0.2])
# you can put a plot into a plot. The first two numbers are the location (lower left corner) of the plot.
# the second two numbers are the size of the figure.

# %%
## multi-axis
fig = plt.figure()
ax1 = fig.add_axes([0.1, 0.5, 0.8, 0.4])  # x-coor of lower-left corner, y-coor of lower left corner, width, height
ax2 = fig.add_axes([0.1, 0.1, 0.8, 0.4])
#
x = np.linspace(0, 10)
ax1.plot(x, np.sin(x))
ax2.plot(x, np.cos(x));
#

# %%
plt.subplot(2, 1, 1)  # you can use subplot; this is two rows 1 column; position 1
plt.plot(x, np.sin(x)); # plot the first curve
plt.subplot(2, 1, 2)    # plot the second subplot the last number refers to the position
plt.plot(x, np.cos(x));

# %%
# Subplot function
for i in range(1, 13):
  ax = plt.subplot(3, 4, i)  # create a grid of 3 rows and 4 columns
  ax.text(0.5, 0.5, str((3, 4, i)),   # Label to show how the subplots are numbered.
          fontsize=12, ha='center')

# %%
# put subplots at the same time.

fig, ax = plt.subplots(3, 4, sharex = 'col', sharey = 'row')  # sharex and sharey puts the axes only on one side instead of each plot.

# %%
## you can also index the subplots
for y in range(3):
  for x in range(4):
    ax[y,x].text(0.5, 0.5, str((y, x)),   # Label to show how the subplots are numbered.
                 fontsize=12, ha='center')
fig

# %%
# plot different size graphs

grid = plt.GridSpec(3,4, wspace = 0.5, hspace = 0.3)
plt.subplot(grid[0,0]);

plt.subplot(grid[0,1:]);
plt.subplot(grid[1,:]);
plt.subplot(grid[2,:2]);
plt.subplot(grid[2,2:]);

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import gridspec

# Generate sample data
np.random.seed(0)
x = np.random.normal(loc=0, scale=1, size=300)
y = np.random.normal(loc=0, scale=1, size=300)

# Set up the figure with gridspec
fig = plt.figure(figsize=(8, 8))
gs = gridspec.GridSpec(4, 4)
ax_main = fig.add_subplot(gs[1:4, 0:3])  # Scatter plot
ax_xhist = fig.add_subplot(gs[0, 0:3], sharex=ax_main)  # Top histogram
ax_yhist = fig.add_subplot(gs[1:4, 3], sharey=ax_main)  # Right histogram

# Scatter plot
ax_main.scatter(x, y, alpha=0.6)


# X histogram
ax_xhist.hist(x, bins=30, color='gray')


# Y histogram
ax_yhist.hist(y, bins=30, orientation='horizontal', color='gray')


plt.tight_layout()
plt.show()

# %% [markdown]
# # Annotations
#
# There is a lot that can be done so check out the matplotlib doc info here: https://matplotlib.org/stable/users/explain/text/annotations.html

# %%
# Add annotations to the grid

plt.figure(figsize = (10,5))

plt.subplot(1,1,1)
plt.scatter(0.2,0.2)
plt.scatter(.8,.4)
plt.scatter(1.75,0.8, s = 100)

# Text
plt.text(0.5,0.5,"Hello!")  # the x and y coordinates followed by what you want to write.
plt.text(0.2,0.2, 'A really important \n data point!')
plt.text(0.25,0.8, "This is how you annotate a graph!")



## Arrows
plt.annotate('Another important data point', xy=(.8,.4), xytext=(.9,.6),  # First, what you want to write followed by xy coordinates of the arrow point, then xy of where the text is.
                    arrowprops=dict(facecolor='black', shrink=0.05))  # shrink prevents it from covering up the point.

plt.annotate('Look at this point!', xy=(1.75,.8), xytext=(1, .2),
                    arrowprops=dict(arrowstyle="->",
                                    connectionstyle="angle3,angleA=0,angleB=-90"));  # angle3 is the connection style that starts horizontally and turns vertically.
                                                                                     # angleA-0 is the starting angle
                                                                                     # agnleB=-90 is the ending angle

plt.xlim(0,2);
plt.ylim(0,1);

plt.grid(True)

# %% [markdown]
# # Ticks

# %%
x = np.linspace(0, 10, 100)
fig, ax = plt.subplots()

ax.plot(x, np.exp(x));

ax.set_yscale('log')  # This sets the graph to log scale.  The ticks on the y axis have changed to reflect this.
ax.grid(True)

# %%
ax = plt.axes(xscale = 'log', yscale = 'log')
ax.plot(x, x**2);
ax.grid(True)

# %%
# you can turn the ticks off
plt.plot([1, 2, 3], [4, 5, 6])
plt.xticks([])  # removes x-axis ticks + labels
plt.yticks([])  # removes y-axis ticks + labels
plt.show()

# %%
fig, ax = plt.subplots()  # create a new figure and axes

ax.plot([1, 2, 3], [4, 5, 6])

ax.minorticks_on()  # turn on minor ticks

ax.tick_params(axis='both', which='minor', length=6, color='r')  # customize minor ticks

plt.show()

# %%
fig, ax = plt.subplots()  # create a new figure and axes

ax.plot([1, 2, 3], [4, 5, 6])

ax.set_xticks([1,2,3], ['Monday','Tuesday','Wednesday']) # Label with strings.

plt.show()

# %%
# You can change the number of ticks.
from matplotlib.ticker import MaxNLocator

fig, ax = plt.subplots()
ax.plot([1, 2, 3], [4, 5, 6])

ax.xaxis.set_major_locator(MaxNLocator(nbins=15))  # up to 15 major ticks
ax.yaxis.set_major_locator(MaxNLocator(nbins=3))   # make three ticks

plt.show()

# %%
# another way to get rid of tick marks.

fig, ax = plt.subplots()
ax.plot([1, 2, 3], [4, 5, 6])

ax.xaxis.set_major_locator(plt.NullLocator())  # gets rid of tick marks
ax.yaxis.set_major_locator(plt.NullLocator())   # gets rid of tick marks

plt.show()

# %% [markdown]
# # Configurations and Style Sheets
#
# More info about matplotlib styles here: https://matplotlib.org/stable/users/explain/customizing.html

# %%
plt.style.use('classic')  # you can call up different styles to use; But will change for the rest of the session.
# create data
t = np.arange(0.0, 2.0, 0.01)
s = np.sin(2*np.pi*t)

plt.plot(t,s);

# %%
plt.style.use('ggplot')  # here is one that mimics R figures.
# create data
t = np.arange(0.0, 2.0, 0.01)
s = np.sin(2*np.pi*t)

plt.plot(t,s);

# %%
print(plt.style.available)  # see what styles are available
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
# You can create your own styles and save them with the extension .mplstyle
# Let's give this a try.
# The following code creates a .mplstyle sheet.
# Define the style parameters
style_params = """
axes.titlesize : 24
axes.labelsize : 20
lines.linewidth : 5
lines.markersize : 10
xtick.labelsize : 16
ytick.labelsize : 16
figure.facecolor : cyan
axes.facecolor : white
axes.edgecolor : black
"""

# Save the style to a .mplstyle file
file_name = "custom_style.mplstyle"
with open(file_name, "w") as f:
    f.write(style_params.strip())

print(f"Style file saved as: {file_name}")

# This should now be saved in your current directory.
# Out:
# Style file saved as: custom_style.mplstyle

# %%
# Let's try the new style.
plt.style.use("custom_style.mplstyle"); # loads from the working directory.
t = np.arange(0.0, 2.0, 0.01)
s = np.sin(2*np.pi*t)

plt.plot(t,s);

# %%
# You can also use cycler
from matplotlib import cycler
colors = cycler('color',
                ['magenta', 'black', 'gray',
                 'pink', 'red', 'orange'])
plt.rc('axes', facecolor='gray', edgecolor='k',
       axisbelow=True, grid=True, prop_cycle=colors)
plt.rc('grid', color='w', linestyle='solid')
plt.rc('xtick', direction='out', color='gray')
plt.rc('ytick', direction='out', color='gray')
plt.rc('patch', edgecolor='k')
plt.rc('lines', linewidth=2)
plt.rc('figure', facecolor='w')

# %%
t = np.arange(0.0, 2.0, 0.01)
s = np.sin(2*np.pi*t)
c = np.cos(2*np.pi*t)
plt.plot(t,s);
plt.plot(t,c);

# It may not be the prettiest, but it is customizable!

# %%
# Let's try it on a different sort of plot
x = np.random.randn(1000)
plt.hist(x);

# %% [markdown]
# # 3D Plotting

# %%
plt.style.use('default')  # Lets change everything back to normal

# %%
fig = plt.figure()
ax = plt.axes(projection='3d') # Create a 3D figure

# %%
 ax = plt.axes(projection='3d')

# Data for a three-dimensional line
x = np.linspace(0, 15, 1000)
y = np.sin(x)
z = np.cos(x)
ax.plot3D(x, y, z, 'gray')  # a 3D corkscrew!

# %%
ax = plt.axes(projection='3d')
# Data for a three-dimensional scatter
x = np.linspace(0, 15, 100)
y = np.sin(x)
z = np.cos(x)
ax.scatter3D(x, y, z, 'gray');  # a 3D corkscrew!

# %%
# We can make 3D contours

#Setup for 3D guassian figure
x = np.linspace(-5, 5, 100)
y = np.linspace(-5,5,100)
X, Y = np.meshgrid(x, y)
x_guass1 = np.exp(-(X/4.5)**2)
y_guass1 = np.exp(-(Y/4.5)**2)
z = x_guass1*y_guass1


# plot
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, z, 40, cmap = 'viridis');

# %%
# change plotting view
ax.view_init(60, 30)

fig

# %%
# plot a wire frame
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_wireframe(X, Y, z, color='m');

# %%
# mesh
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, z, rstride=1, cstride=1,
                cmap='viridis', edgecolor='none');
